# %% [markdown]
# # Dask Array

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 11: Dask
# * https://docs.dask.org/en/latest/array.html
# * JESSE C. DANIEL. Data Science with Python and Dask.

# %%
import dask.array as da
import h5py
import numpy as np
import dask.dataframe as dd
import dask
import os
os.environ['PATH'] += os.pathsep + r'C:\Program Files\Graphviz\bin'

# %%
dask.__version__
# Out:
# '2021.04.0'

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Создайте массив размерностью 1000 на 300000, заполненный числами из стандартного нормального распределения. Исследуйте основные характеристики полученного массива.

# %%
arr_np = np.random.normal(0,1,size = (1000,300000))

# %%
arr_dask = da.random.normal(0,1,size = (1000,300000), chunks = (1000,300000))
arr_dask
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\array\core.py:1401: RuntimeWarning: overflow encountered in long_scalars
#   cbytes = format_bytes(np.prod(self.chunksize) * self.dtype.itemsize)
# dask.array<normal, shape=(1000, 300000), dtype=float64, chunksize=(1000, 300000), chunktype=numpy.ndarray>

# %% [markdown]
# 2. Посчитайте сумму квадратов элементов массива, созданного в задаче 1. Создайте массив `np.array` такого же размера и сравните скорость решения задачи с использование `da.array` и `np.array`

# %%
# %%time
np.power(arr_np,2).sum()
# Out:
# Wall time: 9.76 s
# 300013086.53514826

# %%
# %%time
da.power(arr_dask,2).sum().compute()
# Out:
# Wall time: 17 s
# 299980702.6502893

# %% [markdown]
# 3. Визуализируйте граф вычислений для задачи 2.

# %%
da.power(arr_dask,2).sum().visualize()

# %% [markdown]
# ## Лабораторная работа 11

# %% [markdown]
# 1. Считайте датасет `recipe` из файла `minutes_n_ingredients_full.hdf5` в виде `dask.array`. Укажите аргумент `chunks=(100_000, 3)` при создании массива. Выведите на экран основную информацию о массиве.

# %%
data = h5py.File('11_dask_array_data/minutes_n_ingredients_full.hdf5', 'r')
data_dask = da.from_array(data['/recipe'], chunks=(100_000, 3))
data_dask
# Out:
# dask.array<array, shape=(2231637, 3), dtype=int64, chunksize=(100000, 3), chunktype=numpy.ndarray>

# %% [markdown]
# 2. Вычислите среднее значение по каждому столбцу, кроме первого.

# %%
data_dask[:,1::].mean(axis=0).compute()
# Out:
# array([1004.20805176,    5.4198008 ])

# %% [markdown]
# 3. Исследуйте, как влияет значение аргумента `chunks` при создании `dask.array` на скорость выполнения операции поиска среднего.

# %%
test1_data_dask = da.rechunk(data_dask, chunks = ('auto', 'auto'))
test2_data_dask = da.rechunk(data_dask, chunks = (10000, 3))

# %%
# %%time
test1_data_dask.compute()
# Out:
# Wall time: 38.9 ms
# array([[ 683970,      33,       9],
#        [1089012,      23,       5],
#        [1428572,       0,       5],
#        ...,
#        [1910650,      60,       2],
#        [ 713836,       0,       9],
#        [ 660699,      64,       8]], dtype=int64)

# %%
# %%time
test2_data_dask.compute()
# Out:
# Wall time: 71.8 ms
# array([[ 683970,      33,       9],
#        [1089012,      23,       5],
#        [1428572,       0,       5],
#        ...,
#        [1910650,      60,       2],
#        [ 713836,       0,       9],
#        [ 660699,      64,       8]], dtype=int64)

# %% [markdown]
# ### При увеличении количества чанков в 224 раза скорость вычислений уменьшилась почти вдвое

# %% [markdown]
# 4. Выберите рецепты, время выполнения которых меньше медианного значения

# %%
data_dask_mask = data_dask[data_dask[:,1] < np.median(data_dask[:,1], axis=0).compute()]
data_dask_mask.compute()
# Out:
# array([[1089012,      23,       5],
#        [1428572,       0,       5],
#        [1400250,      24,       1],
#        ...,
#        [1029131,      19,       4],
#        [1700703,       1,       1],
#        [ 713836,       0,       9]], dtype=int64)

# %% [markdown]
# 5. Посчитайте количество каждого из возможных значений кол-ва ингредиентов

# %%
unique, counts = np.unique(data_dask[:,2], return_counts=True)

# %%
for i in range(len(unique.compute())):
    print (f"{unique.compute()[i]} --- {counts.compute()[i]}")
# Out:
# 1 --- 222071
# 2 --- 224158
# 3 --- 229388
# 4 --- 234948
# 5 --- 240720
# 6 --- 244360
# 7 --- 247181
# 8 --- 246747
# 9 --- 246816
# 10 --- 22430
# 11 --- 19094
# 12 --- 15165
# 13 --- 11640
# 14 --- 8284
# 15 --- 6014
# 16 --- 4145
# 17 --- 2793
# 18 --- 1913
# 19 --- 1279
# 20 --- 852
# 21 --- 529
# 22 --- 346
# 23 --- 244
# 24 --- 178
# 25 --- 107
# 26 --- 68
# 27 --- 55
# 28 --- 33
# 29 --- 22
# 30 --- 20
# 31 --- 13
# 32 --- 5
# 33 --- 4
# 34 --- 3
# 35 --- 4
# 36 --- 1
# 37 --- 2
# 38 --- 1
# 39 --- 1
# 40 --- 2
# 43 --- 1

# %% [markdown]
# 6. Найдите максимальную продолжительность рецепта. Ограничьте максимальную продолжительность рецептов сверху значением, равному 75% квантилю.

# %%
# quantile = dd.DataFrame.quantile(data_dask[:,1]) ?!

quantile = np.quantile(data_dask[:,1], .75)
data_dask[data_dask[:,1] < quantile].compute()[:,1].max()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\dask\array\core.py:1488: FutureWarning: The `numpy.quantile` function is not implemented by Dask array. You may want to use the da.map_blocks function or something similar to silence this warning. Your code may stop working in a future release.
#   warnings.warn(
# 48

# %% [markdown]
# 7. Создайте массив `dask.array` из 2 чисел, содержащих ваши предпочтения относительно времени выполнения рецепта и кол-ва ингредиентов. Найдите наиболее похожий (в смысле $L_1$) рецепт из имеющихся в датасете.

# %%
test = np.array([10,5])
x = da.from_array(test, chunks=('auto'))
x.compute()

data_dask[da.fabs(x - data_dask[:,1:]).sum(axis=1).argmin()].compute()
# Out:
# array([2168955,      10,       5], dtype=int64)

# %% [markdown]
# 8. Работая с исходным файлом в формате `hdf5`, реализуйте алгоритм подсчета среднего значения в блочной форме и вычислите с его помощью среднее значение второго столбца в массиве.
#
# Блочный алгоритм вычислений состоит из двух частей:
# 1. загрузка фрагмента за фрагментом данных по `blocksize` элементов и проведение вычислений на этим фрагментом;
# 2. агрегация результатов вычислений на различных фрагментах для получения результата на уровне всего набора данных.
#
# Важно: при работе с `h5py` в память загружаются не все элементы, а только те, которые запрашиваются в данный момент
